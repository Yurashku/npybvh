# %% [markdown]
# # пример использования парсера

# %%
# !pip install -U ipympl matplotlib
# !pip install -U pyquaternion transforms3d

# %%
# %load_ext autoreload
# %autoreload 2

import os, sys, pickle
import matplotlib.pyplot as plt
# from mpl_toolkits import mplot3d
import numpy as np
from transforms3d.euler import euler2mat, mat2euler

from scipy.spatial.transform import Rotation

# import math
# from pyquaternion import Quaternion
# from tqdm import tqdm
# %matplotlib inline

# %%
data_path = 'bvh_data/'
file_pathes = !ls {data_path}*.bvh

# %% [markdown]
# # переведем bvh file в структуру BVH

# %%
import bvh as bvh

# %%
print('Содержится файлов данного формата:', len(file_pathes))
# выберем один из них по номеру
file_path = file_pathes[33]
name = file_path.split('/')[-1].split('.')[0]
print('Выбран:', file_path.split('/')[-1])


# create Bvh parser
anim = bvh.Bvh()
# parser file
anim.parse_file(file_path)
# Out:
# Содержится файлов данного формата: 77
# Выбран: multipleActions1_subject2.bvh

# %%
anim.frames
# Out:
# 4587

# %%
anim.plot_hierarchy()

# %%
# draw the skeleton for the given frame
anim.plot_frame(22)

# %% [markdown]
# # теперь конвертируем обратно в файл

# %%
anim.write_to_bvh('output.bvh')
# Out:
# Wrote "output.bvh"

# %% [markdown]
# # на основании 3D координат создание объекта bvh.Bvh()

# %% [markdown]
# **обязательные** входные параметры:

# %%
# fps для видео-объекта
FPS = 30

# %%
# 3D-координаты частей тела p
p, _ = anim.all_frame_poses()
p.shape
# Out:
# (4587, 27, 3)

# %%
with open('default_bvh_parameters/lafan_init_offsets.pickle', 'rb') as f:
    init_offsets = pickle.load(f)
init_offsets
# Out:
# {'Hips': array([-224.2155  ,   91.52404 ,  295.415894]),
#  'LeftUpLeg': array([ 0.103456,  1.857823, 10.548498]),
#  'LeftLeg': array([ 4.35e+01, -1.90e-05, -2.00e-06]),
#  'LeftFoot': array([ 4.2372204e+01,  2.7000000e-05, -5.0000000e-06]),
#  'LeftToe': array([ 1.7299999e+01, -1.0000000e-06,  0.0000000e+00]),
#  'LeftToe_end': array([0., 0., 0.]),
#  'RightUpLeg': array([  0.103456,   1.857824, -10.548502]),
#  'RightLeg': array([ 4.3500038e+01, -1.5000000e-05,  1.7000000e-05]),
#  'RightFoot': array([ 4.2372261e+01, -1.5000000e-05,  1.5000000e-05]),
#  'RightToe': array([ 1.7299984e+01, -7.0000000e-06, -2.0000000e-06]),
#  'RightToe_end': array([0., 0., 0.]),
#  'Spine': array([ 6.901968e+00, -2.603745e+00, -5.000000e-06]),
#  'Spine1': array([1.25881e+01, 1.40000e-05, 1.30000e-05]),
#  'Spine2': array([ 1.2343204e+01,  8.0000000e-06, -1.0000000e-05]),
#  'Neck': array([2.5832903e+01, 2.0000000e-06, 1.0000000e-05]),
#  'Head': array([ 1.1766598e+01,  1.5000000e-05, -0.0000000e+00]),
#  'Head_end': array([0., 0., 0.]),
#  'LeftShoulder': array([19.745903, -1.480366,  6.000109]),
#  'LeftArm': array([ 1.1284134e+01,  1.0000000e-06, -1.7000000e-05]),
#  'LeftForeArm': array([3.3000042e+01, 1.0000000e-05, 1.5000000e-05]),
#  'LeftHand': array([2.5200022e+01, 1.2000000e-05, 0.0000000e+00]),
#  'LeftHand_end': array([0., 0., 0.]),
#  'RightShoulder': array([19.746094, -1.480373, -6.000069]),
#  'RightArm': array([ 1.1284146e+01, -6.0000000e-06, -1.8000000e-05]),
#  'RightForeArm': array([3.3000103e+01, 6.0000000e-06, 1.6000000e-05]),
#  'RightHand': array([2.5199755e+01, 1.2600000e-04, 4.2300000e-04]),
#  'RightHand_end': array([0., 0., 0.])}

# %%
with open('default_bvh_parameters/lafan_parent_name_dict.pickle', 'rb') as f:
    parent_name_dict = pickle.load(f)
parent_name_dict
# Out:
# {'Hips': None,
#  'LeftUpLeg': 'Hips',
#  'LeftLeg': 'LeftUpLeg',
#  'LeftFoot': 'LeftLeg',
#  'LeftToe': 'LeftFoot',
#  'LeftToe_end': 'LeftToe',
#  'RightUpLeg': 'Hips',
#  'RightLeg': 'RightUpLeg',
#  'RightFoot': 'RightLeg',
#  'RightToe': 'RightFoot',
#  'RightToe_end': 'RightToe',
#  'Spine': 'Hips',
#  'Spine1': 'Spine',
#  'Spine2': 'Spine1',
#  'Neck': 'Spine2',
#  'Head': 'Neck',
#  'Head_end': 'Head',
#  'LeftShoulder': 'Spine2',
#  'LeftArm': 'LeftShoulder',
#  'LeftForeArm': 'LeftArm',
#  'LeftHand': 'LeftForeArm',
#  'LeftHand_end': 'LeftHand',
#  'RightShoulder': 'Spine2',
#  'RightArm': 'RightShoulder',
#  'RightForeArm': 'RightArm',
#  'RightHand': 'RightForeArm',
#  'RightHand_end': 'RightHand'}

# %%
# и соответствие имен номерам в массиве p
joint_name_index = {nm:i for i,nm in enumerate(parent_name_dict.keys())}
joint_name_index
# Out:
# {'Hips': 0,
#  'LeftUpLeg': 1,
#  'LeftLeg': 2,
#  'LeftFoot': 3,
#  'LeftToe': 4,
#  'LeftToe_end': 5,
#  'RightUpLeg': 6,
#  'RightLeg': 7,
#  'RightFoot': 8,
#  'RightToe': 9,
#  'RightToe_end': 10,
#  'Spine': 11,
#  'Spine1': 12,
#  'Spine2': 13,
#  'Neck': 14,
#  'Head': 15,
#  'Head_end': 16,
#  'LeftShoulder': 17,
#  'LeftArm': 18,
#  'LeftForeArm': 19,
#  'LeftHand': 20,
#  'LeftHand_end': 21,
#  'RightShoulder': 22,
#  'RightArm': 23,
#  'RightForeArm': 24,
#  'RightHand': 25,
#  'RightHand_end': 26}

# %% [markdown]
# далее все автоматически

# %%
# %%time
new_anim = bvh.Bvh()
new_anim.extract_from_3D(p, parent_name_dict, joint_name_index, FPS)


# и проверка
new_anim.write_to_bvh('new_output.bvh')
# Out:
# Wrote "new_output.bvh"
# CPU times: user 11.7 s, sys: 48 ms, total: 11.8 s
# Wall time: 11.8 s

# %% [markdown]
# # проверим

# %%
test_anim = bvh.Bvh()
test_anim.parse_file('new_output.bvh')

test_poses, test_angles = test_anim.all_frame_poses()


np.max(test_poses - p),\
np.max(anim.get_initial_poses() - test_anim.get_initial_poses())
# Out:
# (1.9218239316387553e-05, 0.0)

# %%
anim.plot_hierarchy()
test_anim.plot_hierarchy()

anim.plot_frame(22)
test_anim.plot_frame(22)
